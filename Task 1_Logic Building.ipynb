# %%
#1. User Login Check

#Stored credentials
correct_username = "admin"
correct_password = "1234"

#Given credentials (you can modify to test)
username = "admin"
password = "1234"

#Checking login
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful

# %%
#2. Pass / Fail Analyzer

marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students Passed:", pass_count)
print("Total Students Failed:", fail_count)
# Out:
# Total Students Passed: 3
# Total Students Failed: 2

# %%
#3. Simple Data Cleaner

names = [" Monis ", "ravi", " ADITYA "]

cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print("Cleaned Names List:", cleaned_names)
# Out:
# Cleaned Names List: ['monis', 'ravi', 'aditya']

# %%
#4. Message Length Analyzer

messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print(f"Message: '{message}' | Length: {length}")
    
    if length > 10:
        print("-> This message is longer than 10 characters.")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# -> This message is longer than 10 characters.
# Message: 'OK' | Length: 2

# %%
#5. Error Message Detector

logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total ERROR messages:", error_count)
# Out:
# Total ERROR messages: 2
